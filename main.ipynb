# %% [markdown]
# # Importação dos Dados

# %%
import pandas as pd

# %%
df_loja1 = pd.read_csv(r'./data/loja_1.csv', sep=',')
df_loja2 = pd.read_csv(r'./data/loja_2.csv', sep=',')
df_loja3 = pd.read_csv(r'./data/loja_3.csv', sep=',')
df_loja4 = pd.read_csv(r'./data/loja_4.csv', sep=',')

df_loja1.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# ## Conhecendo os Datasets
#
# O dataset inclui as seguintes informações:
#
# - Produto e Categoria: Itens vendidos e suas classificações.
#
# - Preço e Frete: Valores das vendas e custos associados.
#
# - Data de Compra e Local: Informações temporais e geográficas.
#
# - Avaliação da Compra: Feedback dos clientes.
#
# - Tipo de Pagamento e Parcelas: Métodos utilizados pelos clientes.
#
# - Coordenadas Geográficas: Localização das transações.

# %%
print('=== Colunas - Loja 1 ===')
display(df_loja1.dtypes)
print('=== Colunas - Loja 2 ===')
display(df_loja2.dtypes)
print('=== Colunas - Loja 3 ===')
display(df_loja3.dtypes)
print('=== Colunas - Loja 4 ===')
display(df_loja4.dtypes)
# Out:
# === Colunas - Loja 1 ===
# Produto                    object
# Categoria do Produto       object
# Preço                     float64
# Frete                     float64
# Data da Compra             object
# Vendedor                   object
# Local da compra            object
# Avaliação da compra         int64
# Tipo de pagamento          object
# Quantidade de parcelas      int64
# lat                       float64
# lon                       float64
# dtype: object
# === Colunas - Loja 2 ===
# Produto                    object
# Categoria do Produto       object
# Preço                     float64
# Frete                     float64
# Data da Compra             object
# Vendedor                   object
# Local da compra            object
# Avaliação da compra         int64
# Tipo de pagamento          object
# Quantidade de parcelas      int64
# lat                       float64
# lon                       float64
# dtype: object
# === Colunas - Loja 3 ===
# ...

# %% [markdown]
# ## Verificando dados nulos

# %%
df_loja1.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %%
df_loja2.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %%
df_loja3.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %%
df_loja4.isnull().sum()
# Out:
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# dtype: int64

# %% [markdown]
# # Análise de Dados
#
# ## 1. Análise do faturamento

# %%
print('Faturamento total - Loja 1: ', df_loja1['Preço'].sum())
print('Faturamento total - Loja 2: ', df_loja2['Preço'].sum())
print('Faturamento total - Loja 3: ', df_loja3['Preço'].sum())
print('Faturamento total - Loja 4: ', df_loja4['Preço'].sum())

faturamentos = {
    "Loja 1": df_loja1["Preço"].sum(),
    "Loja 2": df_loja2["Preço"].sum(),
    "Loja 3": df_loja3["Preço"].sum(),
    "Loja 4": df_loja4["Preço"].sum(),
}

pd.Series(faturamentos).plot(kind="barh", title="Faturamento por Loja")
# Out:
# Faturamento total - Loja 1:  1534509.12
# Faturamento total - Loja 2:  1488459.06
# Faturamento total - Loja 3:  1464025.03
# Faturamento total - Loja 4:  1384497.58
# <Axes: title={'center': 'Faturamento por Loja'}>

# %% [markdown]
# ## 2. Vendas por Categoria

# %%
import matplotlib.pyplot as plt

# === Preparar os dados ===
dados1 = df_loja1["Categoria do Produto"].value_counts()
dados2 = df_loja2["Categoria do Produto"].value_counts()
dados3 = df_loja3["Categoria do Produto"].value_counts()
dados4 = df_loja4["Categoria do Produto"].value_counts()

# === Criar a figura 2x2 ===
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# --- Loja 1 ---
axes[0, 0].barh(dados1.index, dados1.values)
axes[0, 0].set_title("Categorias mais vendidas – Loja 1")
axes[0, 0].set_xlabel("Quantidade de Produtos Vendidos")
axes[0, 0].set_ylabel("Categoria")
for i, v in enumerate(dados1.values):
    axes[0, 0].text(v, i, str(v), va="center")

# --- Loja 2 ---
axes[0, 1].barh(dados2.index, dados2.values)
axes[0, 1].set_title("Categorias mais vendidas – Loja 2")
axes[0, 1].set_xlabel("Quantidade de Produtos Vendidos")
axes[0, 1].set_ylabel("Categoria")
for i, v in enumerate(dados2.values):
    axes[0, 1].text(v, i, str(v), va="center")

# --- Loja 3 ---
axes[1, 0].barh(dados3.index, dados3.values)
axes[1, 0].set_title("Categorias mais vendidas – Loja 3")
axes[1, 0].set_xlabel("Quantidade de Produtos Vendidos")
axes[1, 0].set_ylabel("Categoria")
for i, v in enumerate(dados3.values):
    axes[1, 0].text(v, i, str(v), va="center")

# --- Loja 4 ---
axes[1, 1].barh(dados4.index, dados4.values)
axes[1, 1].set_title("Categorias mais vendidas – Loja 4")
axes[1, 1].set_xlabel("Quantidade de Produtos Vendidos")
axes[1, 1].set_ylabel("Categoria")
for i, v in enumerate(dados4.values):
    axes[1, 1].text(v, i, str(v), va="center")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Média de Avaliação das Lojas

# %%
# Calcular as médias de avaliação
medias = {
    "Loja 1": df_loja1["Avaliação da compra"].mean(),
    "Loja 2": df_loja2["Avaliação da compra"].mean(),
    "Loja 3": df_loja3["Avaliação da compra"].mean(),
    "Loja 4": df_loja4["Avaliação da compra"].mean(),
}

lojas = list(medias.keys())
valores = list(medias.values())

plt.figure(figsize=(8, 5))
plt.bar(lojas, valores)

plt.title("Média de Avaliação por Loja")
plt.ylabel("Média das Avaliações")

# Inserir valores acima das barras
for i, v in enumerate(valores):
    plt.text(i, v + 0.02, f"{v:.2f}", ha="center")

plt.ylim(0, max(valores) + 0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Produtos Mais e Menos Vendidos

# %%
# Loja 1
vendas1 = df_loja1["Produto"].value_counts()
mais_vendido_1 = vendas1.idxmax()
menos_vendido_1 = vendas1.idxmin()

# Loja 2
vendas2 = df_loja2["Produto"].value_counts()
mais_vendido_2 = vendas2.idxmax()
menos_vendido_2 = vendas2.idxmin()

# Loja 3
vendas3 = df_loja3["Produto"].value_counts()
mais_vendido_3 = vendas3.idxmax()
menos_vendido_3 = vendas3.idxmin()

# Loja 4
vendas4 = df_loja4["Produto"].value_counts()
mais_vendido_4 = vendas4.idxmax()
menos_vendido_4 = vendas4.idxmin()

print("Loja 1 → Mais vendido:", mais_vendido_1, "| Menos vendido:", menos_vendido_1)
print("Loja 2 → Mais vendido:", mais_vendido_2, "| Menos vendido:", menos_vendido_2)
print("Loja 3 → Mais vendido:", mais_vendido_3, "| Menos vendido:", menos_vendido_3)
print("Loja 4 → Mais vendido:", mais_vendido_4, "| Menos vendido:", menos_vendido_4)
# Out:
# Loja 1 → Mais vendido: TV Led UHD 4K | Menos vendido: Headset
# Loja 2 → Mais vendido: Iniciando em programação | Menos vendido: Jogo de tabuleiro
# Loja 3 → Mais vendido: Kit banquetas | Menos vendido: Blocos de montar
# Loja 4 → Mais vendido: Cama box | Menos vendido: Guitarra

# %% [markdown]
# ## 5. Frete Médio por Loja

# %%
media_frete_loja1 = df_loja1["Frete"].mean()
media_frete_loja2 = df_loja2["Frete"].mean()
media_frete_loja3 = df_loja3["Frete"].mean()
media_frete_loja4 = df_loja4["Frete"].mean()

print(f"Custo médio de frete - Loja 1: {media_frete_loja1:.2f}")
print(f"Custo médio de frete - Loja 2: {media_frete_loja2:.2f}")
print(f"Custo médio de frete - Loja 3: {media_frete_loja3:.2f}", )
print(f"Custo médio de frete - Loja 4: {media_frete_loja4:.2f}", )

# Gráfico
lojas = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]
valores = [
    media_frete_loja1,
    media_frete_loja2,
    media_frete_loja3,
    media_frete_loja4
]

plt.figure(figsize=(8,5))
plt.bar(lojas, valores)

plt.title("Custo Médio de Frete por Loja")
plt.ylabel("Valor Médio do Frete (R$)")

# Colocar valores acima das barras
for i, v in enumerate(valores):
    plt.text(i, v + 0.05, f"R$ {v:.2f}", ha="center")

plt.tight_layout()
plt.show()
# Out:
# Custo médio de frete - Loja 1: 34.69
# Custo médio de frete - Loja 2: 33.62
# Custo médio de frete - Loja 3: 33.07
# Custo médio de frete - Loja 4: 31.28

# %% [markdown]
# # Conclusão Final
#
# Com base em todas as análises e visualizações realizadas — incluindo o faturamento total, o desempenho das categorias e produtos, a média das avaliações dos clientes e o custo médio de frete — tornou-se possível identificar, de forma clara e objetiva, qual loja se destaca positivamente e qual apresenta fragilidades mais evidentes ao longo dos indicadores avaliados.
#
# Entre as quatro lojas, observou-se que a **Loja 4** se posiciona consistentemente abaixo das demais em aspectos essenciais. Ela apresenta o menor faturamento, indicando menor força de vendas e menor capacidade de geração de receita. Apesar de possuir o frete médio mais baixo entre as lojas — um ponto que poderia ser positivo do ponto de vista do consumidor — esse fator não foi suficiente para elevar seu desempenho geral, sugerindo que ela enfrenta dificuldades que vão além dos custos logísticos.
#
# Sua média de avaliação, embora não seja a pior, também não se destaca, ficando abaixo das lojas 2 e 3, as quais demonstram níveis mais altos de satisfação do cliente. Além disso, os produtos e categorias com melhor desempenho na Loja 4 não têm a mesma relevância ou volume dos itens mais vendidos nas outras lojas.
#
# Dessa forma, considerando todos os pontos fortes e fracos identificados ao longo desta análise, conclui-se que a Loja 4 é a candidata mais adequada para ser vendida. Ela concentra os indicadores mais fracos entre as quatro unidades, não demonstra vantagens competitivas significativas e apresenta o menor potencial de crescimento, especialmente quando comparada às demais operações.
# Assim, recomenda-se que o Senhor João opte pela venda da Loja 4, preservando as lojas que apresentam maior desempenho, melhor percepção dos clientes e maior contribuição para os resultados do negócio como um todo.

# %% [markdown]
# # Análise Geografica

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,12))

# LOJA 1
plt.subplot(2, 2, 1)
plt.scatter(df_loja1["lon"], df_loja1["lat"], alpha=0.6, s=35)
plt.title("Distribuição Geográfica – Loja 1")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

# LOJA 2
plt.subplot(2, 2, 2)
plt.scatter(df_loja2["lon"], df_loja2["lat"], alpha=0.6, s=35)
plt.title("Distribuição Geográfica – Loja 2")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

# LOJA 3
plt.subplot(2, 2, 3)
plt.scatter(df_loja3["lon"], df_loja3["lat"], alpha=0.6, s=35)
plt.title("Distribuição Geográfica – Loja 3")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

# LOJA 4
plt.subplot(2, 2, 4)
plt.scatter(df_loja4["lon"], df_loja4["lat"], alpha=0.6, s=35)
plt.title("Distribuição Geográfica – Loja 4")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.tight_layout()
plt.show()
